# %%
import gdown

# %%
import os

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'e:\\Tanmoy Saha\\Upskill\\Tech Stack\\Krish Naik Projects\\Machine Learning\\Discarded-Material-Identification-System'

# %%
url = "https://drive.google.com/file/d/1VISKudKNVvNs2cetrolw2YfGwZQU9mFa/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1VISKudKNVvNs2cetrolw2YfGwZQU9mFa'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "data/waste_data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1VISKudKNVvNs2cetrolw2YfGwZQU9mFa
# From (redirected): https://drive.google.com/uc?/export=download&id=1VISKudKNVvNs2cetrolw2YfGwZQU9mFa&confirm=t&uuid=f7e757a8-9955-48c1-b47a-5426fee2c457
# To: e:\Tanmoy Saha\Upskill\Tech Stack\Krish Naik Projects\Machine Learning\Discarded-Material-Identification-System\data\waste_data.zip
# 100%|██████████| 40.1M/40.1M [00:02<00:00, 18.3MB/s]
# 'data/waste_data.zip'

# %%
# %pwd
# Out:
# 'e:\\Tanmoy Saha\\Upskill\\Tech Stack\\Krish Naik Projects\\Machine Learning\\Discarded-Material-Identification-System'
